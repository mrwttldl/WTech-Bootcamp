# %% [markdown]
# # <font color=blue>Assignments for "Logistic Regression"</font>

# %% [markdown]
# - In this assignment, you are going to use your model to predict survival of the Titanic disaster. For this assignment, send a link to a Jupyter notebook containing solutions to the following tasks.
#     - Download [Titanic](https://www.kaggle.com/c/titanic/data) data from Kaggle. The data in the train.csv file meets your need.
#     - Split your data into training and test sets.
#     - Predict the survival based on the test data you split by creating your model.
#     - Is your model's performance satisfactory? Explain.
#     - Try to improve your model's performance by adding or subtracting some variables. <br>
#
# - Explore the advantages and disadvantages of Logistic Regression and discuss with your mentor.

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df=pd.read_csv("train.csv", sep=",")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
def missing_value_table(df):
    missing_value = df.isnull().sum()
    missing_value_percent = 100 * df.isnull().sum() / len(df)
    missing_value_table = pd.concat([missing_value,missing_value_percent], axis = 1)
    missing_value_table_end = missing_value_table.rename(columns = {0 : 'Missing Value', 1 : '% değeri'})
    return missing_value_table_end

# %%
missing_value_table(df)
# Out:
#              Missing Value   % değeri
# PassengerId              0   0.000000
# Survived                 0   0.000000
# Pclass                   0   0.000000
# Name                     0   0.000000
# Sex                      0   0.000000
# Age                    177  19.865320
# SibSp                    0   0.000000
# Parch                    0   0.000000
# Ticket                   0   0.000000
# Fare                     0   0.000000
# Cabin                  687  77.104377
# Embarked                 2   0.224467

# %%
df[df["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df["Embarked"] = imp_mean.fit_transform(df[["Embarked"]])

# %%
df[df["Age"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
from sklearn.impute import KNNImputer
df_numeric = df.select_dtypes(include = ["float64","int64"])
var_names = df_numeric.columns
n_df = np.array(df_numeric)

# %%
n_df[0:10]
# Out:
# array([[ 1.    ,  0.    ,  3.    , 22.    ,  1.    ,  0.    ,  7.25  ],
#        [ 2.    ,  1.    ,  1.    , 38.    ,  1.    ,  0.    , 71.2833],
#        [ 3.    ,  1.    ,  3.    , 26.    ,  0.    ,  0.    ,  7.925 ],
#        [ 4.    ,  1.    ,  1.    , 35.    ,  1.    ,  0.    , 53.1   ],
#        [ 5.    ,  0.    ,  3.    , 35.    ,  0.    ,  0.    ,  8.05  ],
#        [ 6.    ,  0.    ,  3.    ,     nan,  0.    ,  0.    ,  8.4583],
#        [ 7.    ,  0.    ,  1.    , 54.    ,  0.    ,  0.    , 51.8625],
#        [ 8.    ,  0.    ,  3.    ,  2.    ,  3.    ,  1.    , 21.075 ],
#        [ 9.    ,  1.    ,  3.    , 27.    ,  0.    ,  2.    , 11.1333],
#        [10.    ,  1.    ,  2.    , 14.    ,  1.    ,  0.    , 30.0708]])

# %%
imputer = KNNImputer(n_neighbors=4)
new_data = imputer.fit_transform(n_df)
df2=pd.DataFrame(new_data, columns=var_names)
df[["Age"]] = df2.Age

# %%
df[df["Cabin"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.drop(["Cabin"], axis =1, inplace = True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df["Sex"].unique() #we can apply 0-1 transformation
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Embarked"].unique() #we should apply one-hot transformation
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df["Ticket"].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
df.drop(["Name","PassengerId","Ticket"], axis =1, inplace = True)

# %%
df
# Out:
#      Survived  Pclass     Sex    Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.00      1      0   7.2500        S
# 1           1       1  female  38.00      1      0  71.2833        C
# 2           1       3  female  26.00      0      0   7.9250        S
# 3           1       1  female  35.00      1      0  53.1000        S
# 4           0       3    male  35.00      0      0   8.0500        S
# ..        ...     ...     ...    ...    ...    ...      ...      ...
# 886         0       2    male  27.00      0      0  13.0000        S
# 887         1       1  female  19.00      0      0  30.0000        S
# 888         0       3  female  27.25      1      2  23.4500        S
# 889         1       1    male  26.00      0      0  30.0000        C
# 890         0       3    male  32.00      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
lbe = LabelEncoder()
df["Sex"] = lbe.fit_transform(df["Sex"])

# %%
df = pd.concat([df, pd.get_dummies(df["Embarked"])], axis=1).drop("Embarked", axis = 1)
df
# Out:
#      Survived  Pclass  Sex    Age  SibSp  Parch     Fare  C  Q  S
# 0           0       3    1  22.00      1      0   7.2500  0  0  1
# 1           1       1    0  38.00      1      0  71.2833  1  0  0
# 2           1       3    0  26.00      0      0   7.9250  0  0  1
# 3           1       1    0  35.00      1      0  53.1000  0  0  1
# 4           0       3    1  35.00      0      0   8.0500  0  0  1
# ..        ...     ...  ...    ...    ...    ...      ... .. .. ..
# 886         0       2    1  27.00      0      0  13.0000  0  0  1
# 887         1       1    0  19.00      0      0  30.0000  0  0  1
# 888         0       3    0  27.25      1      2  23.4500  0  0  1
# 889         1       1    1  26.00      0      0  30.0000  1  0  0
# 890         0       3    1  32.00      0      0   7.7500  0  1  0
#
# [891 rows x 10 columns]

# %%
y=df["Survived"]
X=df[["Sex", "Pclass", "Age","SibSp","Parch","Fare","C","Q","S"]]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test =  train_test_split(X, y, test_size=0.20, random_state=111)

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(solver='lbfgs', multi_class="ovr")

# %%
log_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
train_accuracy = log_reg.score(X_train, y_train)
test_accuracy = log_reg.score(X_test, y_test)

print('One-vs.-Rest', '-'*30, 
      'Accuracy on Train Data : {:.2f}'.format(train_accuracy), 
      'Accuracy on Test Data  : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# One-vs.-Rest
# ------------------------------
# Accuracy on Train Data : 0.80
# Accuracy on Test Data  : 0.78

# %%
log_reg_mnm = LogisticRegression(multi_class='multinomial', solver='lbfgs')
log_reg_mnm.fit(X_train, y_train)

train_accuracy = log_reg_mnm.score(X_train, y_train)
test_accuracy = log_reg_mnm.score(X_test, y_test)

print('Multinomial (Softmax)', '-'*20, 
      'Accuracy on Train Data : {:.2f}'.format(train_accuracy), 
      'Accuracy on Test Data  : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# Multinomial (Softmax)
# --------------------
# Accuracy on Train Data : 0.80
# Accuracy on Test Data  : 0.78

# %%
print(log_reg.predict(X)[0:10])
# Out:
# [0 1 1 1 0 0 0 0 1 1]

# %%
C_values = [0.001,0.01, 0.1,1,10,100, 1000]

accuracy_values = pd.DataFrame(columns=['C_values', 'Train Accuracy', 'Test Accuracy'])

for c in C_values:
    # Apply logistic regression model to training data
    lr = LogisticRegression(penalty = 'l2', C = c, random_state = 0, solver='lbfgs', multi_class='multinomial')
    lr.fit(X_train, y_train)
    accuracy_values = accuracy_values.append({'C_values': c,
                                              'Train Accuracy': lr.score(X_train, y_train),
                                              'Test Accuracy': lr.score(X_test, y_test)
                                             }, ignore_index=True)
display(accuracy_values)
# Out:
#    C_values  Train Accuracy  Test Accuracy
# 0     0.001        0.695225       0.687151
# 1     0.010        0.765449       0.810056
# 2     0.100        0.801966       0.793296
# 3     1.000        0.804775       0.776536
# 4    10.000        0.801966       0.776536
# 5   100.000        0.804775       0.776536
# 6  1000.000        0.801966       0.776536

# %%
y1=df["Survived"]
X1=df[["Sex", "Pclass", "Age","SibSp","Parch"]]

# %%
from sklearn.model_selection import train_test_split

X1_train, X1_test, y1_train, y1_test =  train_test_split(X1, y1, test_size=0.20, random_state=111)

# %%
from sklearn.linear_model import LogisticRegression

log_reg2 = LogisticRegression(solver='lbfgs', multi_class="ovr")

# %%
log_reg2.fit(X1_train, y1_train)
# Out:
# LogisticRegression(multi_class='ovr')

# %%
train_accuracy = log_reg2.score(X1_train, y1_train)
test_accuracy = log_reg2.score(X1_test, y1_test)

print('One-vs.-Rest', '-'*30, 
      'Accuracy on Train Data : {:.2f}'.format(train_accuracy), 
      'Accuracy on Test Data  : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# One-vs.-Rest
# ------------------------------
# Accuracy on Train Data : 0.79
# Accuracy on Test Data  : 0.78

# %%
log_reg2_mnm = LogisticRegression(multi_class='multinomial', solver='lbfgs')
log_reg2_mnm.fit(X1_train, y1_train)

train_accuracy = log_reg2_mnm.score(X1_train, y1_train)
test_accuracy = log_reg2_mnm.score(X1_test, y1_test)

print('Multinomial (Softmax)', '-'*20, 
      'Accuracy on Train Data : {:.2f}'.format(train_accuracy), 
      'Accuracy on Test Data  : {:.2f}'.format(test_accuracy), sep='\n')
# Out:
# Multinomial (Softmax)
# --------------------
# Accuracy on Train Data : 0.79
# Accuracy on Test Data  : 0.78

# %%
print(log_reg2.predict(X1)[0:5])
# Out:
# [0 1 1 1 0]

# %%
C_values = [0.001,0.01, 0.1,1,10,100, 1000]

accuracy_values = pd.DataFrame(columns=['C_values', 'Train Accuracy', 'Test Accuracy'])

for c in C_values:
    # Apply logistic regression model to training data
    lr = LogisticRegression(penalty = 'l2', C = c, random_state = 0, solver='lbfgs', multi_class='multinomial')
    lr.fit(X1_train, y1_train)
    accuracy_values = accuracy_values.append({'C_values': c,
                                              'Train Accuracy': lr.score(X1_train, y1_train),
                                              'Test Accuracy': lr.score(X1_test, y1_test)
                                             }, ignore_index=True)
display(accuracy_values)
# Out:
#    C_values  Train Accuracy  Test Accuracy
# 0     0.001        0.660112       0.642458
# 1     0.010        0.782303       0.810056
# 2     0.100        0.799157       0.782123
# 3     1.000        0.794944       0.782123
# 4    10.000        0.796348       0.782123
# 5   100.000        0.797753       0.782123
# 6  1000.000        0.797753       0.782123
